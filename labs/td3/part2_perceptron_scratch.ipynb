# %% [markdown]
# # Partie 2 : Implémentation "From Scratch" (Numpy)
#
#
#
# ## Contexte
#
# On rappelle la règle de mise à jour des poids pour un Perceptron simple (Rosenblatt) :
#
# $$\Delta w = \eta \cdot (y - \hat{y}) \cdot x$$
#
# Où $\eta$ est le taux d'apprentissage (learning rate).
#
#
# ## Exercice 2.1 : La Classe Perceptron
#
# Complétez le code aux endroits marqués `TODO`.

# %%
import numpy as np
import matplotlib.pyplot as plt

class Perceptron:
    def __init__(self, learning_rate=0.01, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.weights = None
        self.bias = None
        self.accuracy_history = []

    def activation(self, x):
        """Fonction Heaviside : retourne 1 si x >= 0, sinon 0"""
        return np.where(x >= 0, 1, 0)

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0
        self.accuracy_history = []

        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                # TODO :
                # 1. Calculer la sortie linéaire (z = w.x + b)
                
                # 2. Appliquer l'activation pour avoir y_predicted
                
                # 3. Appliquer la règle de mise à jour pour weights et bias
                pass
            
            predictions = self.predict(X)
            accuracy = np.mean(predictions == y)
            self.accuracy_history.append(accuracy)

    def predict(self, X):
      # TODO : retourner la prédiction du modèle

# %% [markdown]
# ---
#
# ## Exercice 2.2 : Porte ET (AND)

# %%
# Dataset AND
X_and = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
y_and = np.array([0, 0, 0, 1])  # Sortie: 1 seulement si les deux entrées sont 1

perceptron_and = Perceptron(learning_rate=0.1, n_iters=100)


# TODO: Entraînement

# TODO: Affichez les poids finaux et le bias

# TODO: Testez les prédictions


print(f"Prédictions: {predictions}")
print(f"Attendu:     {y_and}")
# Out:
# Poids: [0. 0.]
# Bias: 0
# Prédictions: [1 1 1 1]
# Attendu:     [0 0 0 1]

# %% [markdown]
# ---
#
# ## Exercice 2.3 : Porte OU Exclusif (XOR)
#
# Testez maintenant sur une porte XOR. Que se passe-t-il ?

# %%
# Dataset XOR
X_xor = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
y_xor = np.array([0, 1, 1, 0])  # Sortie: 1 si exactement une entrée est 1

perceptron_xor = Perceptron(learning_rate=0.1, n_iters=100)

# TODO: Entraînement

# TODO: Testez les prédictions

# TODO: Calculez l'accuracy
# Out:
# Prédictions: [1 1 1 1]
# Attendu:     [0 1 1 0]
# Accuracy: 50%

# %% [markdown]
# **Question :** Le modèle arrive-t-il à converger ? Que se passe-t-il et pourquoi ?
