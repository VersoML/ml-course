# %% [markdown]
# # Partie 4 : MLP pour la Régression
# ---
#
# ## Exercice 4.1 : Génération du Dataset
#
# L'objectif est d'entraîner un MLP à approximer la fonction $y = \sin(x) + \text{bruit}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(42)
X = np.linspace(0, 2 * np.pi, 200).reshape(-1, 1)  
noise = np.random.normal(0, 0.1, X.shape)           
y_true = np.sin(X).ravel()                          
y = y_true + noise.ravel()                        

plt.figure(figsize=(10, 5))
plt.scatter(X, y, alpha=0.5, label='Données (sin + bruit)', s=20)
plt.plot(X, y_true, 'b-', linewidth=2, label='Vraie fonction sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dataset: Fonction sinusoïdale avec bruit')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# TODO: Divisez les données (80% train, 20% test)
# TODO: Normalisez les données avec StandardScaler

# %% [markdown]
# ---
#
# ## Exercice 4.2 : MLP avec activation ReLU vs Linéaire
#
# Comparez un MLP avec activation ReLU et un MLP avec activation linéaire.

# %%
# MLP avec activation ReLU (non-linéaire)
# TODO: Entraînez le modèle

# MLP avec activation linéaire (identity)
# TODO: Entraînez le modèle

# %% [markdown]
# ---
#
# ## Exercice 4.3 : Visualisation Comparative
#
# Comparez visuellement les prédictions des deux modèles.

# %%
# TODO: Visualisation comparative

# Graphique 1: MLP avec ReLU
# TODO: Tracez les prédictions ReLU en rouge


# Graphique 2: MLP avec activation linéaire
# TODO: Tracez les prédictions linéaires en rouge

# %% [markdown]
# **Question :** Que remarquez-vous sur la courbe rouge dans le cas linéaire ? Pourquoi le MLP ne peut-il pas approximer une courbe avec des activations linéaires ?
