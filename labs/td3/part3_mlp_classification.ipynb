# %% [markdown]
# # Partie 3 : Classification d'Images & Hyperparamètres

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ---
#
# ## Exercice 3.1 : Préparation des Données
#
# Les réseaux de neurones sont très sensibles à l'échelle des données.

# %%
digits = load_digits()
X, y = digits.data, digits.target

fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='gray')
    ax.set_title(f"Label: {y[i]}")
    ax.axis('off')
plt.suptitle("Exemples du dataset Digits (8x8 pixels)")
plt.tight_layout()
plt.show()

print(f"Shape des données: {X.shape}")
print(f"Valeurs des pixels: min={X.min()}, max={X.max()}")
# Out:
# Shape des données: (1797, 64)
# Valeurs des pixels: min=0.0, max=16.0

# %%
# TODO: Divisez les données (80% train, 20% test)
# TODO: Normalisez les données avec StandardScaler

# %% [markdown]
# **Question :** Pourquoi la normalisation est-elle cruciale pour la descente de gradient ?
#
#
#
# ---
#
# ## Exercice 3.2 : Architecture et Performance
#
# Comparez les trois architectures suivantes :

# %%
# Architecture 1: Le Minimaliste (1 couche cachée, 5 neurones)
# TODO: Entraînez et évaluez


# Architecture 2: Le Standard (1 couche cachée, 64 neurones)
# TODO: Entraînez et évaluez

# Architecture 3: Le Profond (2 couches cachées, 64 neurones chacune)
# TODO: Entraînez et évaluez

# TODO: Comparez les scores

# %% [markdown]
# ---
#
# ## Exercice 3.3 : Analyse des Erreurs
#
# Pour le meilleur modèle, analysez les erreurs avec une matrice de confusion.

# %%
# Sélectionnez le meilleur modèle
best_model = ...

# TODO: Prédictions sur le jeu de test

# TODO: Affichez la matrice de confusion

# TODO: Identifiez les chiffres les plus confondus
